# %% [markdown]
# # Extra Trees
# Was one of the top performing models.
#
# I will make a pipeline, then gridsearch to see if I can get an even better model by adjusting the parameters.

# %%
#imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math

from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error

# import sklearn.preprocessing as preprocessing
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

import pickle
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# # Import

# %%
df = pd.read_csv('../data/1500_sentiment_api.csv')
df.head(5)
# Out:
#         id  latitude  longitude  price shared_status  accommodates  \
# 0      177  39.69551 -104.92489   79.0   entire home             2
# 1      360  39.76758 -105.00316  133.0   entire home             3
# 2  2361919  39.77960 -105.03859   76.0   entire home             2
# 3  2386289  39.76777 -105.03529  150.0   entire home             4
# 4  4992412  39.76822 -105.00249   73.0  private room             2
#
#   accomodation_group  bathrooms  bedrooms  beds_adjusted      neighborhood  \
# 0                0-2        1.0       1.0            1.0  Virginia Village
# 1                3-4        1.0       2.0            2.0          Highland
# 2                0-2        1.0       1.0            1.0          Berkeley
# 3                3-4        1.0       1.0            1.0     West Highland
# 4                0-2        2.0       1.0            1.0          Highland
#
#      city  has_neighborhood_overview  has_reviews  host_in_CO  \
# 0  Denver                          1            1           1
# 1  Denver                          1            1           1
# 2  Denver                          1            1           1
# 3  Denver                          1            1           1
# 4  Denver                          1            0           1
#
#    host_lives_in_neighborhood  host_id            host_name  \
# 0                           1      615                  Joe
# 1                           1      666  Jennifer & Giovanni
# 2                           1  5811115              Annette
# 3                           1   184771              Melanie
# 4                           1  5181201       Danno & Rachel
#
#    host_response_time  host_response_rate  host_acceptance_rate  \
# 0      within an hour                 1.0                  1.00
# 1      within an hour                 1.0                  0.87
# 2  within a few hours                 1.0                  0.81
# 3                 NaN                 NaN                  1.00
# 4                 NaN                 NaN                  0.00
#
#    host_is_superhost host_neighbourhood  host_listings_count  \
# 0                1.0   Virginia Village                  2.0
# 1                1.0           Highland                  4.0
# 2                1.0           Berkeley                  5.0
# 3                0.0      West Highland                  1.0
# 4                0.0           Highland                  3.0
#
#    host_total_listings_count  host_has_profile_pic  host_identity_verified  \
# 0                        2.0                   1.0                     0.0
# 1                        4.0                   1.0                     1.0
# 2                        6.0                   1.0                     0.0
# 3                        2.0                   1.0                     1.0
# 4                        4.0                   1.0                     1.0
#
#    has_host_about  years_hosting  years_of_reviews  license_listed  \
# 0               1           15.0               6.0               1
# 1               1           15.0               4.0               1
# 2               1           10.0               8.0               0
# 3               1           13.0               8.0               1
# 4               1           10.0               0.0               0
#
#    response_time  host_lives_in_neighborhood.1  \
# 0            0.0                             1
# 1            0.0                             1
# 2            1.0                             1
# 3            4.0                             1
# 4            4.0                             1
#
#                                                 name  \
# 0   Tiny Home in the Heart of the City- ECO FRIENDLY
# 1  Sit in the Peaceful Garden of the Chickadee Co...
# 2                          The Cloisters at Berkeley
# 3                        Sunny Sky Loft in Highlands
# 4                Cozy Cottage in Lo Highlands, 2nd b
#
#                                           host_about  \
# 0  I'm originally from Oklahoma, but have lived i...
# 1  We are artists and tinkerers.\r\n \r\nWe enjoy...
# 2  I love people of all ages and types, dogs, lon...
# 3  Things I love: dogs, urban gardening, yoga, ho...
# 4  Danno, 40- yo professional from Aspen, Colorad...
#
#                                          description  \
# 0  160 sq ft + 80 sq ft loft for sleeping, Sleeps...
# 1  Enjoy the famous Colorado weather and unplug i...
# 2  A private studio apartment in an unbeatable ne...
# 3  Why stay in a stuffy old hotel room when you c...
# 4  You are renting the second bedroom of a 2br 2b...
#
#                                neighborhood_overview  \
# 0  Quiet neighborhood next to park, creeks and bi...
# 1  The cottage is located in the center of Lower ...
# 2  Boutiques, bars, restaurants galore! Highlands...
# 3  The neighborhood where the house is located is...
# 4  My house is located on the edge of all the act...
#
#                                            amenities  minimum_nights  \
# 0  ["Hot water", "Long term stays allowed", "Coff...              29
# 1  ["Coffee maker", "Washer", "Bedroom comforts",...              29
# 2  ["Hot water", "Long term stays allowed", "Coff...              30
# 3  ["Hot water", "Long term stays allowed", "Coff...               7
# 4  ["Long term stays allowed", "Free parking on p...              30
#
#    maximum_nights min_stay_group max_stay_group  has_availability  \
# 0             400          month      long_term                 1
# 1              35          month       2_months                 1
# 2            1125          month      long_term                 1
# 3              30           week          month                 1
# 4            1125          month      long_term                 1
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               29               59               89               364
# 1                0                0               30                30
# 2               24               54               84               359
# 3                0                0                0                 0
# 4                0                0                0               183
#
#    instant_bookable  number_of_reviews  number_of_reviews_ltm  \
# 0                 0                120                     24
# 1                 0                174                      7
# 2                 0                 43                      3
# 3                 0                 95                      1
# 4                 0                  0                      0
#
#    number_of_reviews_l30d  review_scores_rating  review_scores_accuracy  \
# 0                       0                  4.85                    4.96
# 1                       1                  4.99                    4.99
# 2                       0                  4.67                    4.74
# 3                       0                  4.91                    4.87
# 4                       0                   NaN                     NaN
#
#    review_scores_cleanliness  review_scores_checkin  \
# 0                       4.89                   4.97
# 1                       4.96                   5.00
# 2                       4.56                   4.67
# 3                       4.89                   4.96
# 4                        NaN                    NaN
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         4.94                    4.85                 4.78
# 1                         5.00                    5.00                 4.91
# 2                         4.60                    4.93                 4.60
# 3                         4.97                    4.93                 4.83
# 4                          NaN                     NaN                  NaN
#
#    reviews_per_month  bike_scores  walk_scores  transit_scores  \
# 0               1.56         84.0         51.0            37.0
# 1               3.26         93.0         90.0            49.0
# 2               0.40         76.0         81.0            34.0
# 3               0.94         75.0         86.0            39.0
# 4                NaN         93.0         90.0            49.0
#
#                                  property_page_links  name_sent_compound  \
# 0  https://www.walkscore.com/score/loc/lat=39.695...              0.6037
# 1  https://www.walkscore.com/score/loc/lat=39.767...              0.4939
# 2  https://www.walkscore.com/score/loc/lat=39.779...              0.0000
# 3  https://www.walkscore.com/score/loc/lat=39.767...              0.4215
# 4  https://www.walkscore.com/score/loc/lat=39.768...              0.0000
#
#    name_sent_pos  name_sent_neg  name_sent_neu  host_sent_compound  \
# 0          0.304            0.0          0.696              0.6948
# 1          0.242            0.0          0.758              0.9694
# 2          0.000            0.0          1.000              0.9769
# 3          0.412            0.0          0.588              0.9716
# 4          0.000            0.0          1.000              0.9049
#
#    host_sent_pos  host_sent_neg  host_sent_neu  description_sent_compound  \
# 0          0.192          0.000          0.808                     0.9476
# 1          0.141          0.023          0.835                     0.9814
# 2          0.278          0.000          0.722                     0.9269
# 3          0.247          0.000          0.753                     0.7761
# 4          0.153          0.024          0.822                     0.7678
#
#    description_sent_pos  description_sent_neg  description_sent_neu  \
# 0                 0.153                 0.069                 0.778
# 1                 0.271                 0.019                 0.709
# 2                 0.150                 0.000                 0.850
# 3                 0.067                 0.023                 0.910
# 4                 0.090                 0.042                 0.869
#
#    neighborhood_sent_compound  neighborhood_sent_pos  neighborhood_sent_neg  \
# 0                      0.0000                  0.000                  0.000
# 1                      0.1531                  0.025                  0.018
# 2                      0.4333                  0.067                  0.026
# 3                      0.9595                  0.138                  0.023
# 4                      0.8760                  0.143                  0.000
#
#    neighborhood_sent_neu  25*k
# 0                  1.000   4.0
# 1                  0.956   6.0
# 2                  0.907   4.0
# 3                  0.839   7.0
# 4                  0.857   3.0

# %%
df[['host_sent_pos', 'host_sent_neg','host_sent_neu','host_sent_compound']].mean()
# Out:
# host_sent_pos         0.142327
# host_sent_neg         0.004322
# host_sent_neu         0.852005
# host_sent_compound    0.493554
# dtype: float64

# %%
df.columns
# Out:
# Index(['id', 'latitude', 'longitude', 'price', 'shared_status', 'accommodates',
#        'accomodation_group', 'bathrooms', 'bedrooms', 'beds_adjusted',
#        'neighborhood', 'city', 'has_neighborhood_overview', 'has_reviews',
#        'host_in_CO', 'host_lives_in_neighborhood', 'host_id', 'host_name',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_has_profile_pic',
#        'host_identity_verified', 'has_host_about', 'years_hosting',
#        'years_of_reviews', 'license_listed', 'response_time',
#        'host_lives_in_neighborhood.1', 'name', 'host_about', 'description',
#        'neighborhood_overview', 'amenities', 'minimum_nights',
#        'maximum_nights', 'min_stay_group', 'max_stay_group',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'instant_bookable',
#        'number_of_reviews', 'number_of_reviews_ltm', 'number_of_reviews_l30d',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'reviews_per_month', 'bike_scores',
#        'walk_scores', 'transit_scores', 'property_page_links',
#        'name_sent_compound', 'name_sent_pos', 'name_sent_neg', 'name_sent_neu',
#        'host_sent_compound', 'host_sent_pos', 'host_sent_neg', 'host_sent_neu',
#        'description_sent_compound', 'description_sent_pos',
#        'description_sent_neg', 'description_sent_neu',
#        'neighborhood_sent_compound', 'neighborhood_sent_pos',
#        'neighborhood_sent_neg', 'neighborhood_sent_neu', '25*k'],
#       dtype='object')

# %% [markdown]
# ### Creating a model

# %%
X = df[[
    'shared_status', 
    'accommodates', 
    'bathrooms', 
    'bedrooms', 
    'beds_adjusted', 
    'neighborhood', 
    'has_neighborhood_overview',
    'host_identity_verified',
    'host_has_profile_pic',
    'has_host_about',
    'host_lives_in_neighborhood', 
    'license_listed',
    'bike_scores', 
    'walk_scores',
    'minimum_nights',
    'maximum_nights',
    'instant_bookable'    
      ]]


y = df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=2022)

# %%
numeric_features = list(X.select_dtypes(include = 'number').columns)
numeric_transformer = Pipeline(steps=[
    ('scaler', StandardScaler())])

categorical_features = list(X.select_dtypes(include = 'object').columns)
categorical_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# Append classifier to preprocessing pipeline.
# Now we have a full prediction pipeline.
pipe = Pipeline(steps=[('preprocessor', preprocessor),
                      ('model', ExtraTreesRegressor())])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('scaler',
#                                                                    StandardScaler())]),
#                                                   ['accommodates', 'bathrooms',
#                                                    'bedrooms', 'beds_adjusted',
#                                                    'has_neighborhood_overview',
#                                                    'host_identity_verified',
#                                                    'host_has_profile_pic',
#                                                    'has_host_about',
#                                                    'host_lives_in_neighborhood',
#                                                    'license_listed',
#                                                    'bike_scores', 'walk_scores',
#                                                    'minimum_nights',
#                                                    'maximum_nights',
#                                                    'instant_bookable']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('onehot',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['shared_status',
#                                                    'neighborhood'])])),
#                 ('model', ExtraTreesRegressor())])

# %%
y_pred = pipe.predict(X_test)
rmse = (mean_squared_error(y_test, y_pred))**0.5
print("RMSE:", rmse)
# Out:
# RMSE: 95.83545558689234

# %%
pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('preprocessor',
#    ColumnTransformer(transformers=[('num',
#                                     Pipeline(steps=[('scaler', StandardScaler())]),
#                                     ['accommodates', 'bathrooms', 'bedrooms',
#                                      'beds_adjusted', 'has_neighborhood_overview',
#                                      'host_identity_verified',
#                                      'host_has_profile_pic', 'has_host_about',
#                                      'host_lives_in_neighborhood',
#                                      'license_listed', 'bike_scores',
#                                      'walk_scores', 'minimum_nights',
#                                      'maximum_nights', 'instant_bookable']),
#                                    ('cat',
#                                     Pipeline(steps=[('onehot',
#                                                      OneHotEncoder(handle_unknown='ignore'))]),
#                                     ['shared_status', 'neighborhood'])])),
#   ('model', ExtraTreesRegressor())],
#  'verbose': False,
#  'preprocessor': ColumnTransformer(transformers=[('num',
#                                   Pipeline(steps=[('scaler', StandardScaler())]),
#                                   ['accommodates', 'bathrooms', 'bedrooms',
#                                    'beds_adjusted', 'has_neighborhood_overview',
#                                    'host_identity_verified',
#                                    'host_has_profile_pic', 'has_host_about',
#                                    'host_lives_in_neighborhood',
#                                    'license_listed', 'bike_scores',
#                                    'walk_scores', 'minimum_nights',
#                                    'maximum_nights', 'instant_bookable']),
#                                  ('cat',
#                                   Pipeline(steps=[('onehot',
#                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                   ['shared_status', 'neighborhood'])]),
#  'model': ExtraTreesRegressor(),
#  'preprocessor__n_jobs': None,
#  'preprocessor__remainder': 'drop',
#  'preprocessor__sparse_threshold': 0.3,
#  'preprocessor__transformer_weights': None,
#  'preprocessor__transformers': [('num',
#    Pipeline(steps=[('scaler', StandardScaler())]),
#    ['accommodates',
#     'bathrooms',
#     'bedrooms',
#     'beds_adjusted',
#     'has_neighborhood_overview',
#     'host_identity_verified',
#     'host_has_profile_pic',
#     'has_host_about',
#     'host_lives_in_neighborhood',
#     'license_listed',
#     'bike_scores',
#     'walk_scores',
#     'minimum_nights',
#     'maximum_nights',
#     'instant_bookable']),
#   ('cat',
#    Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#    ['shared_status', 'neighborhood'])],
#  'preprocessor__verbose': False,
#  'preprocessor__verbose_feature_names_out': True,
#  'preprocessor__num': Pipeline(steps=[('scaler', StandardScaler())]),
#  'preprocessor__cat': Pipeline(steps=[('onehot', OneHotEncoder(handle_unknown='ignore'))]),
#  'preprocessor__num__memory': None,
#  'preprocessor__num__steps': [('scaler', StandardScaler())],
#  'preprocessor__num__verbose': False,
#  'preprocessor__num__scaler': StandardScaler(),
#  'preprocessor__num__scaler__copy': True,
#  'preprocessor__num__scaler__with_mean': True,
#  'preprocessor__num__scaler__with_std': True,
#  'preprocessor__cat__memory': None,
#  'preprocessor__cat__steps': [('onehot',
#    OneHotEncoder(handle_unknown='ignore'))],
#  'preprocessor__cat__verbose': False,
#  'preprocessor__cat__onehot': OneHotEncoder(handle_unknown='ignore'),
#  'preprocessor__cat__onehot__categories': 'auto',
#  'preprocessor__cat__onehot__drop': None,
#  'preprocessor__cat__onehot__dtype': numpy.float64,
#  'preprocessor__cat__onehot__handle_unknown': 'ignore',
#  'preprocessor__cat__onehot__sparse': True,
#  'model__bootstrap': False,
#  'model__ccp_alpha': 0.0,
#  'model__criterion': 'squared_error',
#  'model__max_depth': None,
#  'model__max_features': 'auto',
#  'model__max_leaf_nodes': None,
#  'model__max_samples': None,
#  'model__min_impurity_decrease': 0.0,
#  'model__min_samples_leaf': 1,
#  'model__min_samples_split': 2,
#  'model__min_weight_fraction_leaf': 0.0,
#  'model__n_estimators': 100,
#  'model__n_jobs': None,
#  'model__oob_score': False,
#  'model__random_state': None,
#  'model__verbose': 0,
#  'model__warm_start': False}

# %%
et_params = {
    'model__n_estimators':[100, 150, 200],
    'model__max_depth': [None, 1, 2, 3, 4, 5, 6,7],
    'model__min_samples_leaf' : [1,2]
}

# %%
gs= GridSearchCV(pipe, param_grid=et_params, cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['accommodates',
#                                                                           'bathrooms',
#                                                                           'bedrooms',
#                                                                           'beds_adjusted',
#                                                                           'has_neighborhood_overview',
#                                                                           'host_identity_verified',
#                                                                           'host_has_profile_pic',
#                                                                           'has_host_about',
#                                                                           'host_lives_in_neighborhood',
#                                                                           'license_listed',
#                                                                           'bike_scores',
#                                                                           'walk_scores',
#                                                                           'minimum_nights',
#                                                                           'maximum_nights',
#                                                                           'instant_bookable']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['shared_status',
#                                                                           'neighborhood'])])),
#                                        ('model', ExtraTreesRegressor())]),
#              param_grid={'model__max_depth': [None, 1, 2, 3, 4, 5, 6, 7],
#                          'model__min_samples_leaf': [1, 2],
#                          'model__n_estimators': [100, 150, 200]})

# %%
gs.best_params_
# Out:
# {'max_depth': 7, 'min_samples_leaf': 2, 'n_estimators': 150}

# %%
y_pred = gs.predict(X_test)
rmse = (mean_squared_error(y_test, y_pred))**0.5
print("RMSE:", rmse)
# Out:
# RMSE: 87.34954796479578

# %%
et_params2 = {
    'model__n_estimators':[150],
    'model__max_depth': [None],
    'model__min_samples_leaf' : [2],
    'model__max_features': ['sqrt', None],
    'model__min_weight_fraction_leaf': [x / 10 for x in range(0, 2)]
}

# %%
gs= GridSearchCV(pipe, param_grid=et_params2, cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['accommodates',
#                                                                           'bathrooms',
#                                                                           'bedrooms',
#                                                                           'beds_adjusted',
#                                                                           'has_neighborhood_overview',
#                                                                           'host_identity_verified',
#                                                                           'host_has_profile_pic',
#                                                                           'has_host_about',
#                                                                           'host_lives_in_neighborhood',
#                                                                           'license_listed',
#                                                                           'bike_score...
#                                                                           'maximum_nights',
#                                                                           'instant_bookable']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['shared_status',
#                                                                           'neighborhood'])])),
#                                        ('model', ExtraTreesRegressor())]),
#              param_grid={'model__max_depth': [None],
#                          'model__max_features': ['sqrt', None],
#                          'model__min_samples_leaf': [2],
#                          'model__min_weight_fraction_leaf': [0.0, 0.1],
#                          'model__n_estimators': [150]})

# %%
y_pred = gs.predict(X_test)
rmse = (mean_squared_error(y_test, y_pred))**0.5
print("RMSE:", rmse)
# Out:
# RMSE: 87.31928854965241

# %%
gs.predict(X_test)[0]
# Out:
# 137.11597640294653

# %%
gs.best_params_
# Out:
# {'model__max_depth': None,
#  'model__max_features': 'sqrt',
#  'model__min_samples_leaf': 2,
#  'model__min_weight_fraction_leaf': 0.0,
#  'model__n_estimators': 150}

# %%
et_params3 = {
    'model__n_estimators':[150],
    'model__max_depth': [None],
    'model__min_samples_leaf' : [2],
    'model__max_features': ['sqrt', 'log2'],
    'model__min_weight_fraction_leaf': [0]
}

# %%
gs= GridSearchCV(pipe, param_grid=et_params3, cv=5)

# %%
gs.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['accommodates',
#                                                                           'bathrooms',
#                                                                           'bedrooms',
#                                                                           'beds_adjusted',
#                                                                           'has_neighborhood_overview',
#                                                                           'host_identity_verified',
#                                                                           'host_has_profile_pic',
#                                                                           'has_host_about',
#                                                                           'host_lives_in_neighborhood',
#                                                                           'license_listed',
#                                                                           'bike_score...
#                                                                           'maximum_nights',
#                                                                           'instant_bookable']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('onehot',
#                                                                                           OneHotEncoder(handle_unknown='ignore'))]),
#                                                                          ['shared_status',
#                                                                           'neighborhood'])])),
#                                        ('model', ExtraTreesRegressor())]),
#              param_grid={'model__max_depth': [None],
#                          'model__max_features': ['sqrt', 'log2'],
#                          'model__min_samples_leaf': [2],
#                          'model__min_weight_fraction_leaf': [0],
#                          'model__n_estimators': [150]})

# %%
y_pred = gs.predict(X_test)
rmse = (mean_squared_error(y_test, y_pred))**0.5
print("RMSE:", rmse)
# Out:
# RMSE: 87.14659177079199

# %%
gs.best_params_
# Out:
# {'model__max_depth': None,
#  'model__max_features': 'sqrt',
#  'model__min_samples_leaf': 2,
#  'model__min_weight_fraction_leaf': 0,
#  'model__n_estimators': 150}

# %%
with open('../pickle/owner_model.pkl', 'wb') as f:
    pickle.dump(gs.best_estimator_, f)
